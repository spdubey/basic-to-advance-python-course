# %% [markdown]
# # Pyplot Tutorial:

# %% [markdown]
# **matplotlib.pyplot** is a collection of command style functions that make matplotlib work like MATLAB.
#
# Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#data = pd.read_csv('cleaned_data.csv')
data = pd.read_csv('sales_data.csv')

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# 0       Offline              H   5/28/2010  669165933.0         NaN
# 1        Online              C   8/22/2012  963881480.0   9/15/2012
# 2       Offline              L  05-02-2014  341417157.0  05-08-2014
# 3        Online              C   6/20/2014  514321792.0  07-05-2014
# 4       Offline              L  02-01-2013  115456712.0  02-06-2013
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      9925.0      255.28     159.42     2533654.00  1582243.50     951410.50
# 1      2804.0      205.70     117.11      576782.80   328376.44     248406.36
# 2      1779.0      651.21     524.96     1158502.59   933903.84     224598.75
# 3      8102.0        9.33       6.92       75591.66    56065.84      19525.82
# 4      5062.0      651.21     524.96     3296425.02  2657347.52     639077.50

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data = data.sort_values(by = ['Order Date'])

# %%
'''
# Sample
plt.plot([2,4, 6, 4])
plt.ylabel("Numbers")
plt.xlabel('Indices')
plt.title('MyPlot')
plt.show()
'''


# on data set
plt.plot(sorted(data['Total Profit']))
plt.ylabel("Numbers")
plt.xlabel('Indices')
plt.title('MyPlot')
plt.show()

# %% [markdown]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3].

# %% [markdown]
# **plot x versus y**

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('squares')
plt.xlabel('numbers')
plt.grid() # grid on
plt.show()


# on data

#sorted_data = data.sortby(['Order Data'])
grp = data[['Order Date', 'Total Profit']].groupby(['Order Date']).sum()
print(grp.head())
plt.plot(grp['Total Profit'])
plt.ylabel("Total Profit")
plt.xlabel('Order Date')
plt.title('MyPlot')
plt.show()
# Out:
#             Total Profit
# Order Date
# 2010-02-02     166635.36
# 2010-02-06          0.00
# 2010-05-07      14031.02
# 2010-05-28     951410.50
# 2010-06-30     727423.20

# %% [markdown]
# For every x, y pair of arguments, there is an optional third argument which is the **format string** that indicates the color and line type of the plot.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.grid()
plt.show()

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use **numpy arrays**. In fact, all sequences are converted to numpy arrays internally.

# %%
import numpy as np

# %%
import numpy as np
t = np.arange(0., 5., 0.2) 

#blue dashes, red squares and green triangles
plt.plot(t, t**2, 'b--', label='^2')#   'rs',   'g^')
plt.plot(t,t**2.2, 'rs', label='^2.2')
plt.plot(t, t**2.5, 'g^', label='^2.5')
plt.grid()
plt.legend() # add legend based on line labels
plt.show()

# %% [markdown]
# # Controlling line properties

# %% [markdown]
# **use keyword args**

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y, linewidth=5.0)
plt.show()

# %% [markdown]
# **use the setp() **

# %%
x1 = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
x2 = [1, 2, 3, 4]
y2 = [2, 4, 6, 8]
lines = plt.plot(x1, y1, x2, y2)

# use keyword args
plt.setp(lines[0], color='r', linewidth=2.0)

# or MATLAB style string value pairs
plt.setp(lines[1], 'color', 'g', 'linewidth', 2.0)

plt.grid()

# %% [markdown]
# # working with multiple figures and axes

# %%
Hi  All, As I had told , I have attached image showing how you can plot multiple figures(specifically was asked 3X3) in for loop. Hope it helps.

# %%
for i in [1,2,3]:
    plt.figure(i)
    print("***canvas number {}********".format(i))
    for x in range(1,10):
        plt.subplot(3,3,x) # here x = rows, y = cols, x = figure number in the plot canvas
        plt.grid()
        plt.plot([1,2,3])
    plt.show()
# Out:
# ***canvas number 1********
# ***canvas number 2********
# ***canvas number 3********

# %%
plt.figure(1)                # the first figure
plt.subplot(221)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(222)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

#plt.figure(1)                # figure 1 current; subplot(212) still current
#plt.subplot(211)             # make subplot(211) in figure1 current
#plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.show()

# %% [markdown]
# ### Let us look at the scatter plot

# %%
plt.scatter(list(range(len(data))), data['Total Profit'])

# %% [markdown]
# ### Let us look at the distribution plot

# %%
plt.hist( data['Total Profit'], bins = 10)
# Out:
# (array([38., 15., 12., 11.,  9.,  2.,  3.,  4.,  3.,  2.]),
#  array([1.25802000e+03, 1.73124422e+05, 3.44990824e+05, 5.16857226e+05,
#         6.88723628e+05, 8.60590030e+05, 1.03245643e+06, 1.20432283e+06,
#         1.37618924e+06, 1.54805564e+06, 1.71992204e+06]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Let us look at the bar plot

# %%
g = data.groupby('Sales Channel').sum()['Total Profit']
print(g)
x_pos = np.arange(len(g)*8, step=8)
plot = plt.bar(x_pos, g, color='b', width=3, align='center')
plt.xticks(x_pos, g.index, rotation=90)
plt.xlabel('Sales Channel')
plt.ylabel('Profit')
#plt.show()
plt.savefig('Sales_channel_Total_Profit.png', bbox_inches='tight')
# Out:
# Sales Channel
# Offline    24914912.25
# Online     17189403.60
# Name: Total Profit, dtype: float64

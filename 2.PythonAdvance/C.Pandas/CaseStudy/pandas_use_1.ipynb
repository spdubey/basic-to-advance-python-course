# %% [markdown]
# ### <span style="color:Red">Let us start by importing pandas library</span>.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# ### <span style="color:Red"> let us read the data</span>.
#     we can use fle source as csv,excel, sql server, hadoop etc

# %%
data = pd.read_csv('sales_data.csv')

# %%
data
# Out:
#                                 Region                Country  \
# 0                Australia and Oceania                 Tuvalu
# 1    Central America and the Caribbean                Grenada
# 2                               Europe                 Russia
# 3                   Sub-Saharan Africa  Sao Tome and Principe
# 4                   Sub-Saharan Africa                 Rwanda
# ..                                 ...                    ...
# 98                  Sub-Saharan Africa                   Mali
# 99                                Asia               Malaysia
# 100                 Sub-Saharan Africa           Sierra Leone
# 101                      North America                 Mexico
# 102                 Sub-Saharan Africa             Mozambique
#
#            Item Type Sales Channel Order Priority  Order Date     Order ID  \
# 0          Baby Food       Offline              H   5/28/2010  669165933.0
# 1             Cereal        Online              C   8/22/2012  963881480.0
# 2    Office Supplies       Offline              L  05-02-2014  341417157.0
# 3             Fruits        Online              C   6/20/2014  514321792.0
# 4    Office Supplies       Offline              L  02-01-2013  115456712.0
# ..               ...           ...            ...         ...          ...
# 98           Clothes        Online              M   7/26/2011  512878119.0
# 99            Fruits       Offline              L  11-11-2011  810711038.0
# 100       Vegetables       Offline              C  06-01-2016  728815257.0
# 101    Personal Care       Offline              M   7/30/2015  559427106.0
# 102        Household       Offline              L  02-10-2012  665095412.0
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0           NaN      9925.0      255.28     159.42     2533654.00  1582243.50
# 1     9/15/2012      2804.0      205.70     117.11      576782.80   328376.44
# 2    05-08-2014      1779.0      651.21     524.96     1158502.59   933903.84
# 3    07-05-2014      8102.0        9.33       6.92       75591.66    56065.84
# 4    02-06-2013      5062.0      651.21     524.96     3296425.02  2657347.52
# ..          ...         ...         ...        ...            ...         ...
# 98   09-03-2011       888.0      109.28      35.84       97040.64    31825.92
# 99   12/28/2011      6267.0        9.33       6.92       58471.11    43367.64
# 100   6/29/2016      1485.0      154.06      90.93      228779.10   135031.05
# 101  08-08-2015      5767.0       81.73      56.67      471336.91   326815.89
# 102   2/15/2012      5367.0      668.27     502.54     3586605.09  2697132.18
#
#      Total Profit
# 0       951410.50
# 1       248406.36
# 2       224598.75
# 3        19525.82
# 4       639077.50
# ..            ...
# 98       65214.72
# 99       15103.47
# 100      93748.05
# 101     144521.02
# 102     889472.91
#
# [103 rows x 14 columns]

# %%
d = {'Name' : ['abhi', 'shreyank','Arjun'], 'age' : [1,2,3]}

# %%
pd.DataFrame(d)
# Out:
#        Name  age
# 0      abhi    1
# 1  shreyank    2
# 2     Arjun    3

# %% [markdown]
# ### <span style="color:Red"> Lets us look at the data first and couple of information</span>.

# %% [markdown]
# ### <span style="color:Blue">1) shape</span>.

# %%
data.shape # I can find out that total 100 rows and 14 column are present
# we can also use directly len() function to fint the length of the data frame
#len(data)
# Out:
# (103, 14)

# %% [markdown]
# ### <span style="color:Blue">2) head()</span>.

# %%
# it prints top 5 rows in data, you can use data.head(15) and it will give top 15 rows or any number as a parameter in head() funtion
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# 0       Offline              H   5/28/2010  669165933.0         NaN
# 1        Online              C   8/22/2012  963881480.0   9/15/2012
# 2       Offline              L  05-02-2014  341417157.0  05-08-2014
# 3        Online              C   6/20/2014  514321792.0  07-05-2014
# 4       Offline              L  02-01-2013  115456712.0  02-06-2013
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      9925.0      255.28     159.42     2533654.00  1582243.50     951410.50
# 1      2804.0      205.70     117.11      576782.80   328376.44     248406.36
# 2      1779.0      651.21     524.96     1158502.59   933903.84     224598.75
# 3      8102.0        9.33       6.92       75591.66    56065.84      19525.82
# 4      5062.0      651.21     524.96     3296425.02  2657347.52     639077.50

# %% [markdown]
# ### <span style="color:Blue">3) tail()</span>.

# %%
# lets look at the tail of the data, same thig apply to tail as well, you can pass number of rows
data.tail()
# Out:
#                  Region       Country      Item Type Sales Channel  \
# 98   Sub-Saharan Africa          Mali        Clothes        Online
# 99                 Asia      Malaysia         Fruits       Offline
# 100  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 101       North America        Mexico  Personal Care       Offline
# 102  Sub-Saharan Africa    Mozambique      Household       Offline
#
#     Order Priority  Order Date     Order ID   Ship Date  Units Sold  \
# 98               M   7/26/2011  512878119.0  09-03-2011       888.0
# 99               L  11-11-2011  810711038.0  12/28/2011      6267.0
# 100              C  06-01-2016  728815257.0   6/29/2016      1485.0
# 101              M   7/30/2015  559427106.0  08-08-2015      5767.0
# 102              L  02-10-2012  665095412.0   2/15/2012      5367.0
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 98       109.28      35.84       97040.64    31825.92      65214.72
# 99         9.33       6.92       58471.11    43367.64      15103.47
# 100      154.06      90.93      228779.10   135031.05      93748.05
# 101       81.73      56.67      471336.91   326815.89     144521.02
# 102      668.27     502.54     3586605.09  2697132.18     889472.91

# %% [markdown]
# ### <span style="color:Blue">4) iloc() and loc()</span>.

# %%
dummy = pd.read_csv('iloc_loc_exp.csv', index_col = 'ID')

# %%
dummy.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object', name='ID')

# %%
dummy = pd.read_csv('iloc_loc_exp.csv')
dummy
# Out:
#   ID                             Region                Country  \
# 0  a              Australia and Oceania                 Tuvalu
# 1  b  Central America and the Caribbean                Grenada
# 2  c                             Europe                 Russia
# 3  d                 Sub-Saharan Africa  Sao Tome and Principe
# 4  e                 Sub-Saharan Africa                 Rwanda
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0        Baby Food       Offline              H   5/28/2010  669165933
# 1           Cereal        Online              C   8/22/2012  963881480
# 2  Office Supplies       Offline              L  05-02-2014  341417157
# 3           Fruits        Online              C   6/20/2014  514321792
# 4  Office Supplies       Offline              L  02-01-2013  115456712
#
#     Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0         NaN        9925      255.28     159.42     2533654.00  1582243.50
# 1   9/15/2012        2804      205.70     117.11      576782.80   328376.44
# 2  05-08-2014        1779      651.21     524.96     1158502.59   933903.84
# 3  07-05-2014        8102        9.33       6.92       75591.66    56065.84
# 4  02-06-2013        5062      651.21     524.96     3296425.02  2657347.52
#
#    Total Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# 4     639077.50

# %%
dummy.loc[['a','c'], ['Region','Country']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4d790275be37> in <module>
# ----> 1 dummy.loc[['a','c'], ['Region','Country']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1278         # ugly hack for GH #836
#    1279         if self._multi_take_opportunity(tup):
# -> 1280             return self._multi_take(tup)
#    1281
#    1282         # no shortcut needed
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1337         d = {
#    1338             axis: self._get_listlike_indexer(key, axis)
# -> 1339             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#    1340         }
#    1341         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#    1337         d = {
#    1338             axis: self._get_listlike_indexer(key, axis)
# -> 1339             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#    1340         }
#    1341         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['a', 'c'], dtype='object')] are in the [index]"

# %%
# I can also see the data by using iloc() function
data.iloc[0:5, 1:7] # here we have used two things, row indexing and column indexing
# Out:
#                  Country        Item Type Sales Channel Order Priority  \
# 0                 Tuvalu        Baby Food       Offline              H
# 1                Grenada           Cereal        Online              C
# 2                 Russia  Office Supplies       Offline              L
# 3  Sao Tome and Principe           Fruits        Online              C
# 4                 Rwanda  Office Supplies       Offline              L
#
#    Order Date     Order ID
# 0   5/28/2010  669165933.0
# 1   8/22/2012  963881480.0
# 2  05-02-2014  341417157.0
# 3   6/20/2014  514321792.0
# 4  02-01-2013  115456712.0

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# 0       Offline              H   5/28/2010  669165933.0         NaN
# 1        Online              C   8/22/2012  963881480.0   9/15/2012
# 2       Offline              L  05-02-2014  341417157.0  05-08-2014
# 3        Online              C   6/20/2014  514321792.0  07-05-2014
# 4       Offline              L  02-01-2013  115456712.0  02-06-2013
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      9925.0      255.28     159.42     2533654.00  1582243.50     951410.50
# 1      2804.0      205.70     117.11      576782.80   328376.44     248406.36
# 2      1779.0      651.21     524.96     1158502.59   933903.84     224598.75
# 3      8102.0        9.33       6.92       75591.66    56065.84      19525.82
# 4      5062.0      651.21     524.96     3296425.02  2657347.52     639077.50

# %%
# here, we can access the data using the labels instead of giving number in column index

data.loc[0:5,2:5 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-403449478bf4> in <module>
#       1 # here, we can access the data using the labels instead of giving number in column index
#       2
# ----> 3 data.loc[0:5,2:5 ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1286                 continue
#    1287
# -> 1288             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1289
#    1290         return retval
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909         if isinstance(key, slice):
#    1910             self._validate_key(key, axis)
# -> 1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
#    1913             return self._getbool_axis(key, axis=axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1794         labels = obj._get_axis(axis)
#    1795         indexer = labels.slice_indexer(
# -> 1796             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1797         )
#    1798
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    4711         slice(1, 3)
#    4712         """
# -> 4713         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4714
#    4715         # return a slice
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    4924         start_slice = None
#    4925         if start is not None:
# -> 4926             start_slice = self.get_slice_bound(start, "left", kind)
#    4927         if start_slice is None:
#    4928             start_slice = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    4836         # For datetime indices label may be a string that has to be converted
#    4837         # to datetime boundary according to its resolution.
# -> 4838         label = self._maybe_cast_slice_bound(label, side, kind)
#    4839
#    4840         # we need to look up the label
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4788         # this is rejected (generally .loc gets you here)
#    4789         elif is_integer(label):
# -> 4790             self._invalid_indexer("slice", label)
#    4791
#    4792         return label
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3075         """
#    3076         raise TypeError(
# -> 3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#    3079         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [2] of <class 'int'>

# %% [markdown]
# ### <span style="color:Blue">5) let us look at all the column names</span>.

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
'date' in 'Ship Date'.lower()
# Out:
# True

# %%
useful_cols = []
for col in data.columns:
    if not 'date' in col.lower():
        useful_cols.append(col)

# %%
data[useful_cols]
# Out:
#                                 Region                Country  \
# 0                Australia and Oceania                 Tuvalu
# 1    Central America and the Caribbean                Grenada
# 2                               Europe                 Russia
# 3                   Sub-Saharan Africa  Sao Tome and Principe
# 4                   Sub-Saharan Africa                 Rwanda
# ..                                 ...                    ...
# 98                  Sub-Saharan Africa                   Mali
# 99                                Asia               Malaysia
# 100                 Sub-Saharan Africa           Sierra Leone
# 101                      North America                 Mexico
# 102                 Sub-Saharan Africa             Mozambique
#
#            Item Type Sales Channel Order Priority     Order ID  Units Sold  \
# 0          Baby Food       Offline              H  669165933.0      9925.0
# 1             Cereal        Online              C  963881480.0      2804.0
# 2    Office Supplies       Offline              L  341417157.0      1779.0
# 3             Fruits        Online              C  514321792.0      8102.0
# 4    Office Supplies       Offline              L  115456712.0      5062.0
# ..               ...           ...            ...          ...         ...
# 98           Clothes        Online              M  512878119.0       888.0
# 99            Fruits       Offline              L  810711038.0      6267.0
# 100       Vegetables       Offline              C  728815257.0      1485.0
# 101    Personal Care       Offline              M  559427106.0      5767.0
# 102        Household       Offline              L  665095412.0      5367.0
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0        255.28     159.42     2533654.00  1582243.50     951410.50
# 1        205.70     117.11      576782.80   328376.44     248406.36
# 2        651.21     524.96     1158502.59   933903.84     224598.75
# 3          9.33       6.92       75591.66    56065.84      19525.82
# 4        651.21     524.96     3296425.02  2657347.52     639077.50
# ..          ...        ...            ...         ...           ...
# 98       109.28      35.84       97040.64    31825.92      65214.72
# 99         9.33       6.92       58471.11    43367.64      15103.47
# 100      154.06      90.93      228779.10   135031.05      93748.05
# 101       81.73      56.67      471336.91   326815.89     144521.02
# 102      668.27     502.54     3586605.09  2697132.18     889472.91
#
# [103 rows x 12 columns]

# %%
cost_clms = []
for clm in data.columns:
    if 'cost' in clm.lower():
        cost_clms.append(clm)
        print(clm)
# Out:
# Unit Cost
# Total Cost

# %%
cost_clms
# Out:
# ['Unit Cost', 'Total Cost']

# %% [markdown]
# ### <span style="color:Blue">7) Before doing any kind of manipulation(deleting or dropping) on my data, let me make a copy of my data first in case i will need it in later stage</span>.

# %%
data_copied = data.copy()

# %% [markdown]
# ### <span style="color:Blue">8) I am not going to analyse anything on date columns, let us drop those columns</span>.

# %% [markdown]
# #### a) there are two way to do that, more trivial way  is create a list with all the columns you want to delete then use function drop()

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
col_to_drop = ['Order Date', 'Ship Date']
print("Printing the list with trivial method :", col_to_drop)
# a) faster and automated way is to create a list with all the columns using for loop
col_to_drop = []
for col in data.columns:
    if 'date' in col.lower():
        col_to_drop.append(col)
print("Printing the list with looping method :", col_to_drop)
# Out:
# Printing the list with trivial method : ['Order Date', 'Ship Date']
# Printing the list with looping method : ['Order Date', 'Ship Date']

# %%
data
# Out:
#                                 Region                Country  \
# 0                Australia and Oceania                 Tuvalu
# 1    Central America and the Caribbean                Grenada
# 2                               Europe                 Russia
# 3                   Sub-Saharan Africa  Sao Tome and Principe
# 4                   Sub-Saharan Africa                 Rwanda
# ..                                 ...                    ...
# 98                  Sub-Saharan Africa                   Mali
# 99                                Asia               Malaysia
# 100                 Sub-Saharan Africa           Sierra Leone
# 101                      North America                 Mexico
# 102                 Sub-Saharan Africa             Mozambique
#
#            Item Type Sales Channel Order Priority  Order Date     Order ID  \
# 0          Baby Food       Offline              H   5/28/2010  669165933.0
# 1             Cereal        Online              C   8/22/2012  963881480.0
# 2    Office Supplies       Offline              L  05-02-2014  341417157.0
# 3             Fruits        Online              C   6/20/2014  514321792.0
# 4    Office Supplies       Offline              L  02-01-2013  115456712.0
# ..               ...           ...            ...         ...          ...
# 98           Clothes        Online              M   7/26/2011  512878119.0
# 99            Fruits       Offline              L  11-11-2011  810711038.0
# 100       Vegetables       Offline              C  06-01-2016  728815257.0
# 101    Personal Care       Offline              M   7/30/2015  559427106.0
# 102        Household       Offline              L  02-10-2012  665095412.0
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0           NaN      9925.0      255.28     159.42     2533654.00  1582243.50
# 1     9/15/2012      2804.0      205.70     117.11      576782.80   328376.44
# 2    05-08-2014      1779.0      651.21     524.96     1158502.59   933903.84
# 3    07-05-2014      8102.0        9.33       6.92       75591.66    56065.84
# 4    02-06-2013      5062.0      651.21     524.96     3296425.02  2657347.52
# ..          ...         ...         ...        ...            ...         ...
# 98   09-03-2011       888.0      109.28      35.84       97040.64    31825.92
# 99   12/28/2011      6267.0        9.33       6.92       58471.11    43367.64
# 100   6/29/2016      1485.0      154.06      90.93      228779.10   135031.05
# 101  08-08-2015      5767.0       81.73      56.67      471336.91   326815.89
# 102   2/15/2012      5367.0      668.27     502.54     3586605.09  2697132.18
#
#      Total Profit
# 0       951410.50
# 1       248406.36
# 2       224598.75
# 3        19525.82
# 4       639077.50
# ..            ...
# 98       65214.72
# 99       15103.47
# 100      93748.05
# 101     144521.02
# 102     889472.91
#
# [103 rows x 14 columns]

# %% [markdown]
# ### <span style="color:Blue">9) Let us now drop the column we decided in previous step again two ways(two type of codes)</span>.

# %% [markdown]
# #### a) directly dropping from data frame

# %%
col_to_drop
# Out:
# ['Order Date', 'Ship Date']

# %%
data.drop(col_to_drop, axis=1, inplace=True)

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority     Order ID  Units Sold  Unit Price  \
# 0       Offline              H  669165933.0      9925.0      255.28
# 1        Online              C  963881480.0      2804.0      205.70
# 2       Offline              L  341417157.0      1779.0      651.21
# 3        Online              C  514321792.0      8102.0        9.33
# 4       Offline              L  115456712.0      5062.0      651.21
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42     2533654.00  1582243.50     951410.50
# 1     117.11      576782.80   328376.44     248406.36
# 2     524.96     1158502.59   933903.84     224598.75
# 3       6.92       75591.66    56065.84      19525.82
# 4     524.96     3296425.02  2657347.52     639077.50

# %% [markdown]
# #### a) another way that is used( recommend using previous method), but first check whether it will run???

# %%
data = data.drop(col_to_drop, axis=1)

#Note:
# The reason the above code did not run is we have already dropped the column hence it throws error of 'KeyError'
# which means then the columns you passed does not exists
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-32bd57e329aa> in <module>
# ----> 1 data = data.drop(col_to_drop, axis=1)
#       2
#       3 #Note:
#       4 # The reason the above code did not run is we have already dropped the column hence it throws error of 'KeyError'
#       5 # which means then the columns you passed does not exists
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Order Date' 'Ship Date'] not found in axis"

# %% [markdown]
# ### <span style="color:Blue">10) This brings to another concept in data preparation, many a times you want to add few columns in your data from other data set which is data merging</span>.

# %%
len(data.columns)
# Out:
# 12

# %%
# another way of finding length
data.columns.__len__()
# Out:
# 12

# %%
len(data.columns)
# Out:
# 12

# %%
data_copied.columns.__len__() # two extra columns because my copied data still have 'Ship Date' and 'Order Date'
# Out:
# 14

# %%
merged_data = data.merge(data_copied)
merged_data
# Out:
#                                 Region                Country  \
# 0                Australia and Oceania                 Tuvalu
# 1    Central America and the Caribbean                Grenada
# 2                               Europe                 Russia
# 3                   Sub-Saharan Africa  Sao Tome and Principe
# 4                   Sub-Saharan Africa                 Rwanda
# ..                                 ...                    ...
# 106                 Sub-Saharan Africa                   Mali
# 107                               Asia               Malaysia
# 108                 Sub-Saharan Africa           Sierra Leone
# 109                      North America                 Mexico
# 110                 Sub-Saharan Africa             Mozambique
#
#            Item Type Sales Channel Order Priority     Order ID  Units Sold  \
# 0          Baby Food       Offline              H  669165933.0      9925.0
# 1             Cereal        Online              C  963881480.0      2804.0
# 2    Office Supplies       Offline              L  341417157.0      1779.0
# 3             Fruits        Online              C  514321792.0      8102.0
# 4    Office Supplies       Offline              L  115456712.0      5062.0
# ..               ...           ...            ...          ...         ...
# 106          Clothes        Online              M  512878119.0       888.0
# 107           Fruits       Offline              L  810711038.0      6267.0
# 108       Vegetables       Offline              C  728815257.0      1485.0
# 109    Personal Care       Offline              M  559427106.0      5767.0
# 110        Household       Offline              L  665095412.0      5367.0
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 0        255.28     159.42     2533654.00  1582243.50     951410.50
# 1        205.70     117.11      576782.80   328376.44     248406.36
# 2        651.21     524.96     1158502.59   933903.84     224598.75
# 3          9.33       6.92       75591.66    56065.84      19525.82
# 4        651.21     524.96     3296425.02  2657347.52     639077.50
# ..          ...        ...            ...         ...           ...
# 106      109.28      35.84       97040.64    31825.92      65214.72
# 107        9.33       6.92       58471.11    43367.64      15103.47
# 108      154.06      90.93      228779.10   135031.05      93748.05
# 109       81.73      56.67      471336.91   326815.89     144521.02
# 110      668.27     502.54     3586605.09  2697132.18     889472.91
#
#      Order Date   Ship Date
# 0     5/28/2010         NaN
# 1     8/22/2012   9/15/2012
# 2    05-02-2014  05-08-2014
# 3     6/20/2014  07-05-2014
# 4    02-01-2013  02-06-2013
# ..          ...         ...
# 106   7/26/2011  09-03-2011
# 107  11-11-2011  12/28/2011
# 108  06-01-2016   6/29/2016
# 109   7/30/2015  08-08-2015
# 110  02-10-2012   2/15/2012
#
# [111 rows x 14 columns]

# %% [markdown]
# ![title](merge_options.jpg)

# %%
# Let us look at couple of examples
import pandas as pd
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

left
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %%
right
# Out:
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %% [markdown]
# ### Merge Two DataFrames on a Key

# %%
pd.merge(left,right,on='id')
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %% [markdown]
# ### Merge Two DataFrames on Multiple Keys

# %%
pd.merge(left,right,on=['id','subject_id'])
# Out:
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %% [markdown]
# ### left

# %%
pd.merge(left, right, on='subject_id', how='left')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     1    Alex       sub1   NaN    NaN
# 1     2     Amy       sub2   1.0  Billy
# 2     3   Allen       sub4   2.0  Brian
# 3     4   Alice       sub6   4.0  Bryce
# 4     5  Ayoung       sub5   5.0  Betty

# %% [markdown]
# ### Right

# %%
pd.merge(left, right, on='subject_id', how='right')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   2.0     Amy       sub2     1  Billy
# 1   3.0   Allen       sub4     2  Brian
# 2   4.0   Alice       sub6     4  Bryce
# 3   5.0  Ayoung       sub5     5  Betty
# 4   NaN     NaN       sub3     3   Bran

# %% [markdown]
# ### Outer

# %%
pd.merge(left, right, how='outer', on='subject_id')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0   1.0    Alex       sub1   NaN    NaN
# 1   2.0     Amy       sub2   1.0  Billy
# 2   3.0   Allen       sub4   2.0  Brian
# 3   4.0   Alice       sub6   4.0  Bryce
# 4   5.0  Ayoung       sub5   5.0  Betty
# 5   NaN     NaN       sub3   3.0   Bran

# %% [markdown]
# ### Inner

# %%
pd.merge(left, right, on='subject_id', how='inner')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     2     Amy       sub2     1  Billy
# 1     3   Allen       sub4     2  Brian
# 2     4   Alice       sub6     4  Bryce
# 3     5  Ayoung       sub5     5  Betty

# %% [markdown]
# ### <span style="color:Blue">11) Let us now look at some stats/info about the column</span>.

# %% [markdown]
# ### info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 12 columns):
# Region            96 non-null object
# Country           99 non-null object
# Item Type         99 non-null object
# Sales Channel     97 non-null object
# Order Priority    100 non-null object
# Order ID          100 non-null float64
# Units Sold        102 non-null float64
# Unit Price        98 non-null float64
# Unit Cost         102 non-null float64
# Total Revenue     99 non-null float64
# Total Cost        101 non-null float64
# Total Profit      99 non-null float64
# dtypes: float64(7), object(5)
# memory usage: 9.8+ KB

# %% [markdown]
# ### describe()

# %%
data.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   102.000000   98.000000  102.000000   9.900000e+01
# mean   5.430247e+08  5089.686275  281.173878  199.607745   1.434936e+06
# std    2.665254e+08  2744.828459  238.911604  192.726190   1.481287e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   6.279090e+03
# 25%    3.215533e+08  2866.250000   81.730000   35.840000   2.986909e+05
# 50%    5.354181e+08  5097.000000  179.880000  117.110000   7.935180e+05
# 75%    7.907551e+08  7303.750000  437.200000  339.350000   2.513090e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  9.900000e+01
# mean   9.368894e+05  4.418101e+05
# std    1.060752e+06  4.319986e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.223581e+05
# 50%    3.635664e+05  2.964483e+05
# 75%    1.716181e+06  6.390775e+05
# max    4.509794e+06  1.719922e+06

# %% [markdown]
# ### <span style="color:Blue">12) Let us now remove the duplicates from the dataframe</span>.

# %%
dummy = pd.DataFrame({
   'id':[1,2,3,2,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Amy', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub2','sub5']})

# %%
dummy
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   2     Amy       sub2
# 4   5  Ayoung       sub5

# %%
dummy[~dummy.duplicated()]
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 4   5  Ayoung       sub5

# %%
data[data.duplicated()]
# Out:
#                 Region     Country        Item Type Sales Channel  \
# 5   Sub-Saharan Africa      Rwanda  Office Supplies       Offline
# 26  Sub-Saharan Africa      Rwanda  Office Supplies       Offline
# 72  Sub-Saharan Africa  The Gambia             Meat        Online
#
#    Order Priority     Order ID  Units Sold  Unit Price  Unit Cost  \
# 5               L  115456712.0      5062.0      651.21     524.96
# 26              L  115456712.0      5062.0      651.21     524.96
# 72              M  825304400.0      4767.0      421.89     364.69
#
#     Total Revenue  Total Cost  Total Profit
# 5      3296425.02  2657347.52      639077.5
# 26     3296425.02  2657347.52      639077.5
# 72     2011149.63  1738477.23      272672.4

# %% [markdown]
# ### detecting and dropping duplicate values with dummy df

# %%
dup = pd.DataFrame({
   'id':[1,2,3,4,5,2,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung','Amy','Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5','sub2','sub5']})

dup
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
# 5   2     Amy       sub2
# 6   5  Ayoung       sub5

# %%
dup.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
#dup[~dup.duplicated()] # look at the duplicated rows
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %%
dup
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
# 5   2     Amy       sub2
# 6   5  Ayoung       sub5

# %%
dup.drop_duplicates(keep = 'first')
#dup.drop_duplicates(keep = 'last')
#dup.drop_duplicates(keep = False)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5

# %% [markdown]
# ### <span style="color:Blue">13) Checking unique values in data frame</span>.

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority     Order ID  Units Sold  Unit Price  \
# 0       Offline              H  669165933.0      9925.0      255.28
# 1        Online              C  963881480.0      2804.0      205.70
# 2       Offline              L  341417157.0      1779.0      651.21
# 3        Online              C  514321792.0      8102.0        9.33
# 4       Offline              L  115456712.0      5062.0      651.21
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42     2533654.00  1582243.50     951410.50
# 1     117.11      576782.80   328376.44     248406.36
# 2     524.96     1158502.59   933903.84     224598.75
# 3       6.92       75591.66    56065.84      19525.82
# 4     524.96     3296425.02  2657347.52     639077.50

# %%
data.nunique(dropna = False)
# Out:
# Region             8
# Country           76
# Item Type         13
# Sales Channel      3
# Order Priority     5
# Order ID          98
# Units Sold        99
# Unit Price        13
# Unit Cost         13
# Total Revenue     97
# Total Cost        99
# Total Profit      97
# dtype: int64

# %%
len(data['Region'].unique())
# Out:
# 8

# %%
for col in data.columns:
    print(col, "-----", len(data[col].unique()))
# Out:
# Region ----- 8
# Country ----- 76
# Item Type ----- 13
# Sales Channel ----- 3
# Order Priority ----- 5
# Order ID ----- 98
# Units Sold ----- 99
# Unit Price ----- 13
# Unit Cost ----- 13
# Total Revenue ----- 97
# Total Cost ----- 99
# Total Profit ----- 97

# %%
unique = []
col_names = []
for col in data.columns:
    unique.append(len(data[col].unique()))
    col_names.append(col)

# %%
print(unique)
print(col_names)
# Out:
# [8, 76, 13, 3, 5, 98, 99, 13, 13, 97, 99, 97]
# ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order ID', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']

# %%
pd.DataFrame({'column names' : col_names, 'unique_vals' : unique})
# Out:
#       column names  unique_vals
# 0           Region            8
# 1          Country           76
# 2        Item Type           13
# 3    Sales Channel            3
# 4   Order Priority            5
# 5         Order ID           98
# 6       Units Sold           99
# 7       Unit Price           13
# 8        Unit Cost           13
# 9    Total Revenue           97
# 10      Total Cost           99
# 11    Total Profit           97

# %%
import matplotlib.pyplot as plt
plt.bar(col_names, unique)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### <span style="color:Blue">14) Print all the rows of europe region ( Data filtering/slicing)</span>.

# %%
data[((data['Region'] == 'Europe') & 
      (data['Sales Channel'] == 'Online') & 
      (data['Total Revenue'] < 500000))]
# data.Region
# Out:
#     Region         Country      Item Type Sales Channel Order Priority  \
# 16  Europe        Bulgaria        Clothes        Online              M
# 22  Europe        Portugal      Baby Food        Online              H
# 25  Europe        Moldova   Personal Care        Online              L
# 49  Europe     Switzerland  Personal Care        Online              M
# 52  Europe         Albania        Clothes        Online              C
# 60  Europe  United Kingdom      Household        Online              L
#
#        Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 16  972292029.0      1673.0      109.28      35.84      182825.44    59960.32
# 22  860673511.0      1273.0      255.28     159.42      324971.44   202941.66
# 25  740147912.0      5070.0       81.73      56.67      414371.10   287316.90
# 49  617667090.0       273.0       81.73      56.67       22312.29    15470.91
# 52  385383069.0      2269.0      109.28      35.84      247956.32    81320.96
# 60  955357205.0       282.0      668.27     502.54      188452.14   141716.28
#
#     Total Profit
# 16     122865.12
# 22     122029.78
# 25     127054.20
# 49       6841.38
# 52     166635.36
# 60      46735.86

# %% [markdown]
# ### <span style="color:Blue">15) Total Profit in Europe region(Sum of profit on condition)</span>.

# %%
(data[data['Region'] == 'Europe']['Total Profit'].sum()) / len((data[data['Region'] == 'Europe']['Total Profit']))
# Out:
# 482504.559047619

# %%
data[data['Region'] == 'Europe']['Total Profit'].sum()
# data[datadata['Region'] == 'Europe']['Total Profit'].mean()
# data[data['Region'] == 'Europe']['Total Profit'].median()
# Out:
# 10132595.739999998

# %%
data[data['Region'] == 'Europe']['Total Profit'].mean()
# Out:
# 506629.7869999999
